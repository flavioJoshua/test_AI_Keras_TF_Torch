# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten




print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_visible_devices(physical_devices[0], 'GPU')  # Use the first GPU
# Out:
# Num GPUs Available:  2

# %%
import cv2 as cv 
import numpy as np 

#img= cv.imread("/home/flavio/Pictures/img.png")
img=np.zeros((500,500),dtype='uint8')


cv.imshow("test " ,img)
cv.waitKey(0)
# Out:
# QObject::moveToThread: Current thread (0x2dec4f0) is not the object's thread (0x35a5ea0).
# Cannot move to target thread (0x2dec4f0)
#
# QObject::moveToThread: Current thread (0x2dec4f0) is not the object's thread (0x35a5ea0).
# Cannot move to target thread (0x2dec4f0)
#
# QObject::moveToThread: Current thread (0x2dec4f0) is not the object's thread (0x35a5ea0).
# Cannot move to target thread (0x2dec4f0)
#
# QObject::moveToThread: Current thread (0x2dec4f0) is not the object's thread (0x35a5ea0).
# Cannot move to target thread (0x2dec4f0)
#
# QObject::moveToThread: Current thread (0x2dec4f0) is not the object's thread (0x35a5ea0).
# Cannot move to target thread (0x2dec4f0)
#
# QObject::moveToThread: Current thread (0x2dec4f0) is not the object's thread (0x35a5ea0).
# Cannot move to target thread (0x2dec4f0)
#
# QObject::moveToThread: Current thread (0x2dec4f0) is not the object's thread (0x35a5ea0).
# Cannot move to target thread (0x2dec4f0)
#
# ...

# %%
import numpy as np

array = np.array([1, 2, 3])
print(array.shape)
new_array = np.expand_dims(array, axis=0)  # Aggiunge una nuova dimensione lungo l'asse 0
new_array.shape
# Out:
# (1, 3)
